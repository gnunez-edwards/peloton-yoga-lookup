# %%
from pylotoncycle import PylotonCycle
import os

USERNAME = "gabrielan2016@gmail.com"
PASSWORD = "Nunez1998!"

peloton = PylotonCycle(USERNAME, PASSWORD)

me = peloton.GetMe()
print("Logged in as:", me.get("username"))

workouts = peloton.GetRecentWorkouts(5)

print("Number of workouts:", len(workouts))

for workout in workouts:
    print(workout.keys())
    print(workout)
    print("-" * 50)
# Out:
# Logged in as: gnunez1994
# Number of workouts: 5
# dict_keys(['created_at', 'device_type', 'end_time', 'fitness_discipline', 'has_pedaling_metrics', 'has_leaderboard_metrics', 'id', 'is_total_work_personal_record', 'is_outdoor', 'metrics_type', 'name', 'peloton_id', 'platform', 'start_time', 'status', 'timezone', 'title', 'total_work', 'user_id', 'workout_type', 'total_video_watch_time_seconds', 'total_video_buffering_seconds', 'v2_total_video_watch_time_seconds', 'v2_total_video_buffering_seconds', 'total_music_audio_play_seconds', 'total_music_audio_buffer_seconds', 'service_id', 'created', 'device_time_created_at', 'strava_id', 'fitbit_id', 'is_skip_intro_available', 'pause_time_remaining', 'pause_time_elapsed', 'is_paused', 'strength_plan_id', 'strength_plan_overlay_metadata', 'ratings', 'is_3p_fit_feed_workout', 'is_non_partner_3p_fit_feed_workout', 'is_first_party_or_partner_3p_workout', 'pace_target_type', 'has_paused', 'is_pause_available', 'ride', 'total_heart_rate_zone_durations', 'average_effort_score', 'achievement_templates', 'leaderboard_rank', 'total_leaderboard_users', 'leaderboard_distance_rank', 'total_leaderboard_distance_users', 'ftp_info', 'device_type_display_name', 'metadata', 'is_3p_digital_workout', 'performance_graph', 'instructor_name'])
# {'created_at': 1780487378, 'device_type': 'iPhone', 'end_time': 1780489376, 'fitness_discipline': 'yoga', 'has_pedaling_metrics': False, 'has_leaderboard_metrics': False, 'id': '7578bd9ef76f438bbece2c40c0b61d34', 'is_total_work_personal_record': False, 'is_outdoor': False, 'metrics_type': None, 'name': 'Yoga Workout', 'peloton_id': 'e92cd51edcb0439fb1651daaae01d995', 'platform': 'iOS_app', 'start_time': 1780487438, 'status': 'COMPLETE', 'timezone': 'America/Detroit', 'title': None, 'total_work': 0.0, 'user_id': '8268ac98132549909d804933254576d5', 'workout_type': 'class', 'total_video_watch_time_seconds': 0, 'total_video_buffering_seconds': 0, 'v2_total_video_watch_time_seconds': 2009, 'v2_total_video_buffering_seconds': 0, 'total_music_audio_play_seconds': None, 'total_music_audio_buffer_seconds': None, 'service_id': None, 'created': 1780487378, 'device_time_created_at': 1780472978, 'strava_id': None, 'fitbit_id': None, 'is_skip_intro_available': True, 'pause_time_remaining': None, 'pause_time_elapsed': None, 'is_paused': False, 'strength_plan_id': None, 'strength_plan_overlay_metadata': None, 'ratings': {'perceived_effort_rating': None}, 'is_3p_fit_feed_workout': False, 'is_non_partner_3p_fit_feed_workout': False, 'is_first_party_or_partner_3p_workout': True, 'pace_target_type': None, 'has_paused': False, 'is_pause_available': False, 'ride': {'content_availability': 'digital_and_above', 'content_availability_level': 'digital_and_above', 'free_for_limited_time': False, 'is_limited_ride': False, 'availability': {'is_available': True, 'reason': None}, 'class_type_ids': ['56c834e143d4423799fc1d3f3fd70ec8'], 'content_provider': 'peloton', 'content_format': 'video', 'description': "In this active, vinyasa-style yoga class, we'll flow from one pose to the next, linking movements with the breath. Hone your inner focus as you develop strength, flexibility and balance.", 'difficulty_estimate': 6.090534979423868, 'overall_estimate': 1.0, 'difficulty_rating_avg': 6.090534979423868, 'difficulty_rating_count': 243, 'difficulty_level': 'intermediate', 'duration': 1800, 'equipment_ids': [], 'equipment_tags': [], 'explicit_rating': 0, 'extra_images': [], 'fitness_discipline': 'yoga', 'fitness_discipline_display_name': 'Yoga', 'has_closed_captions': True, 'has_pedaling_metrics': False, 'home_peloton_id': '7951f237311b47e087fda664058d971e', 'id': '7092dd7db4b94b22b855494e4255173a', 'image_url': 'https://s3.amazonaws.com/peloton-ride-images/7092dd7db4b94b22b855494e4255173a/img_bd762739d8ab486e886203c86e8ca23d', 'instructor_id': '6c4b9f8582b84ab1bb1225d3e396e92e', 'individual_instructor_ids': [], 'is_archived': True, 'is_closed_caption_shown': True, 'is_explicit': False, 'has_free_mode': False, 'is_live_in_studio_only': False, 'language': 'english', 'origin_locale': 'en-US', 'length': 2032, 'live_stream_id': '7092dd7db4b94b22b855494e4255173a-live', 'live_stream_url': None, 'location': 'psny-studio-2', 'metrics': ['heart_rate', 'calories'], 'original_air_time': 1769793961, 'overall_rating_avg': 1.0, 'overall_rating_count': 284, 'pedaling_start_offset': 60, 'pedaling_end_offset': 1860, 'pedaling_duration': 1800, 'rating': 0, 'ride_type_id': '56c834e143d4423799fc1d3f3fd70ec8', 'ride_type_ids': ['56c834e143d4423799fc1d3f3fd70ec8'], 'sample_vod_stream_url': None, 'sample_preview_stream_url': None, 'scheduled_start_time': 1769794200, 'series_id': '23ade71a057b4809a3ef2ccfee814f98', 'sold_out': False, 'studio_peloton_id': '9416a48287d34349a35f8ea5d5d8003e', 'title': '30 min Yoga Flow', 'total_ratings': 953, 'total_in_progress_workouts': 0, 'total_workouts': 10000, 'vod_stream_url': None, 'vod_stream_id': '7092dd7db4b94b22b855494e4255173a-vod', 'captions': ['de-DE', 'en-US', 'es-ES'], 'user_caption_locales': [], 'join_tokens': {'on_demand': 'eyJob21lX3BlbG90b25faWQiOiBudWxsLCAicmlkZV9pZCI6ICI3MDkyZGQ3ZGI0Yjk0YjIyYjg1NTQ5NGU0MjU1MTczYSIsICJzdHVkaW9fcGVsb3Rvbl9pZCI6IG51bGwsICJ0eXBlIjogIm9uX2RlbWFuZCJ9'}, 'flags': [], 'is_dynamic_video_eligible': False, 'is ...
# --------------------------------------------------
# dict_keys(['created_at', 'device_type', 'end_time', 'fitness_discipline', 'has_pedaling_metrics', 'has_leaderboard_metrics', 'id', 'is_total_work_personal_record', 'is_outdoor', 'metrics_type', 'name', 'peloton_id', 'platform', 'start_time', 'status', 'timezone', 'title', 'total_work', 'user_id', 'workout_type', 'total_video_watch_time_seconds', 'total_video_buffering_seconds', 'v2_total_video_watch_time_seconds', 'v2_total_video_buffering_seconds', 'total_music_audio_play_seconds', 'total_music_audio_buffer_seconds', 'service_id', 'created', 'device_time_created_at', 'strava_id', 'fitbit_id', 'is_skip_intro_available', 'pause_time_remaining', 'pause_time_elapsed', 'is_paused', 'strength_plan_id', 'strength_plan_overlay_metadata', 'ratings', 'is_3p_fit_feed_workout', 'is_non_partner_3p_fit_feed_workout', 'is_first_party_or_partner_3p_workout', 'pace_target_type', 'has_paused', 'is_pause_available', 'ride', 'achievement_templates', 'leaderboard_rank', 'total_leaderboard_users', 'leaderboard_distance_rank', 'total_leaderboard_distance_users', 'ftp_info', 'device_type_display_name', 'metadata', 'is_3p_digital_workout', 'performance_graph', 'instructor_name'])
# {'created_at': 1780422076, 'device_type': 'apple_health', 'end_time': 1780419686, 'fitness_discipline': 'walking', 'has_pedaling_metrics': False, 'has_leaderboard_metrics': False, 'id': '7f09d7ab5c59431593f323f5cd767e29', 'is_total_work_personal_record': False, 'is_outdoor': True, 'metrics_type': None, 'name': 'Walking Workout', 'peloton_id': None, 'platform': 'iOS_app', 'start_time': 1780418791, 'status': 'COMPLETE', 'timezone': 'Etc/GMT+4', 'title': '14 min 55 sec Outdoor Walking', 'total_work': 0.0, 'user_id': '8268ac98132549909d804933254576d5', 'workout_type': 'freestyle', 'total_video_watch_time_seconds': 0, 'total_video_buffering_seconds': 0, 'v2_total_video_watch_time_seconds': None, 'v2_total_video_buffering_seconds': None, 'total_music_audio_play_seconds': None, 'total_music_audio_buffer_seconds': None, 'service_id': 8, 'created': 1780422076, 'device_time_created_at': 1780404391, 'strava_id': None, 'fitbit_id': None, 'is_skip_intro_available': False, 'pause_time_remaining': None, 'pause_time_elapsed': None, 'is_paused': False, 'strength_plan_id': None, 'strength_plan_overlay_metadata': None, 'ratings': {'perceived_effort_rating': None}, 'is_3p_fit_feed_workout': True, 'is_non_partner_3p_fit_feed_workout': True, 'is_first_party_or_partner_3p_workout': False, 'pace_target_type': None, 'has_paused': False, 'is_pause_available': False, 'ride': {'id': '00000000000000000000000000000000', 'is_archived': False, 'title': '14 min 55 sec Outdoor Walking', 'scheduled_start_time': 1780418791, 'duration': 895, 'instructor': {'name': '14 MIN 55 SEC OUTDOOR WALKING', 'image_url': 'https://s3.amazonaws.com/peloton-ride-images/just-walk-outdoor.png'}}, 'achievement_templates': [], 'leaderboard_rank': None, 'total_leaderboard_users': 0, 'leaderboard_distance_rank': None, 'total_leaderboard_distance_users': None, 'ftp_info': {'ftp': 0, 'ftp_source': None, 'ftp_workout_id': None}, 'device_type_display_name': 'Apple Health', 'metadata': {}, 'is_3p_digital_workout': False, 'performance_graph': {'duration': 895, 'is_class_plan_shown': False, 'segment_list': [], 'seconds_since_pedaling_start': [139, 201, 262, 337, 406, 468, 532, 594, 655, 717, 768, 821, 874, 895], 'average_summaries': [{'display_name': 'Avg Pace', 'display_unit': 'min/mi', 'value': 31.05, 'slug': 'avg_pace'}, {'display_name': 'Avg Speed', 'display_unit': 'mph', 'value': 1.9, 'slug': 'avg_speed'}], 'summaries': [{'display_name': 'Distance', 'display_unit': 'mi', 'value': 0.4805, 'slug': 'distance'}, {'display_name': 'Elevation', 'display_unit': 'ft', 'value': 0, 'slug': 'elevation'}, {'display_name': 'Calories', 'display_unit': 'kcal', 'value': 42, 'slug': 'calories'}], 'metrics': [{'display_name': 'Heart Rate', 'display_unit': 'bpm', 'max_value': 121, 'average_value': 113, 'values': [0, 0, 121, 0, 0, 0, 109, 0, 0, 112, 116, 117, 118, 118], 'slug': 'heart_rate', 'zones': [{'display_name': 'Zone 1', 'slug': 'zone1', 'range': '<124 bpm', 'duration': 602, 'max_value': 123, 'min_value': 0}, {'display_name': 'Zone 2', 'slug': 'zone2', 'range': '124-143 bpm', 'duration': 0, 'max_value': 143, 'min_value': 124}, {'display_name': 'Zone 3', 'slug': 'zone3', 'range': '144-162 bpm', 'duration': 0, 'max_value': 162, 'min_value': 144}, {'display_name': 'Zone 4', 'slug': 'zone4', 'range': '163-181 bpm', 'duration': 0, 'max_value': 181, 'min_value': 163}, {'display_name': 'Zone 5', 'slug': 'zone5', 'range': '>=182 bpm', 'duration': 0, 'max_value': 192, 'min_value': 182}], 'missing_data_duration': 293}], 'has_apple_watch_metrics': False, 'location_data': [], 'is_location_data_accurate': None, 'splits_data': {'distance_marker_display_unit': 'mi', 'elevation_change_display_unit': 'ft', 'splits': [{'distance_marker': 0.48, 'order': 1, 'seconds': 1863.0, 'elevation_change': -11.0, 'has_floor_segment': False, 'is_best': False}]}, 'splits_metrics': {'header': [{'slug': 'mi', 'display_name': 'mi'}, {'slug': 'total_time', 'display_name': 'Total Time'}, {'slug': 'pace', 'display_name': 'Pace'}, {'slug' ...
# --------------------------------------------------
# dict_keys(['created_at', 'device_type', 'end_time', 'fitness_discipline', 'has_pedaling_metrics', 'has_leaderboard_metrics', 'id', 'is_total_work_personal_record', 'is_outdoor', 'metrics_type', 'name', 'peloton_id', 'platform', 'start_time', 'status', 'timezone', 'title', 'total_work', 'user_id', 'workout_type', 'total_video_watch_time_seconds', 'total_video_buffering_seconds', 'v2_total_video_watch_time_seconds', 'v2_total_video_buffering_seconds', 'total_music_audio_play_seconds', 'total_music_audio_buffer_seconds', 'service_id', 'created', 'device_time_created_at', 'strava_id', 'fitbit_id', 'is_skip_intro_available', 'pause_time_remaining', 'pause_time_elapsed', 'is_paused', 'strength_plan_id', 'strength_plan_overlay_metadata', 'ratings', 'is_3p_fit_feed_workout', 'is_non_partner_3p_fit_feed_workout', 'is_first_party_or_partner_3p_workout', 'pace_target_type', 'has_paused', 'is_pause_available', 'ride', 'total_heart_rate_zone_durations', 'average_effort_score', 'achievement_templates', 'leaderboard_rank', 'total_leaderboard_users', 'leaderboard_distance_rank', 'total_leaderboard_distance_users', 'ftp_info', 'device_type_display_name', 'metadata', 'is_3p_digital_workout', 'performance_graph', 'instructor_name'])
# {'created_at': 1780400666, 'device_type': 'iPhone', 'end_time': 1780402607, 'fitness_discipline': 'yoga', 'has_pedaling_metrics': False, 'has_leaderboard_metrics': False, 'id': '3b9caecffa0b4069a5bf5a365f6dbf14', 'is_total_work_personal_record': False, 'is_outdoor': False, 'metrics_type': None, 'name': 'Yoga Workout', 'peloton_id': 'eadfcdc2a2a44a8db94e54bd899c9c38', 'platform': 'iOS_app', 'start_time': 1780400726, 'status': 'COMPLETE', 'timezone': 'America/Detroit', 'title': None, 'total_work': 0.0, 'user_id': '8268ac98132549909d804933254576d5', 'workout_type': 'class', 'total_video_watch_time_seconds': 0, 'total_video_buffering_seconds': 0, 'v2_total_video_watch_time_seconds': 1943, 'v2_total_video_buffering_seconds': 1, 'total_music_audio_play_seconds': None, 'total_music_audio_buffer_seconds': None, 'service_id': None, 'created': 1780400666, 'device_time_created_at': 1780386265, 'strava_id': None, 'fitbit_id': None, 'is_skip_intro_available': True, 'pause_time_remaining': None, 'pause_time_elapsed': None, 'is_paused': False, 'strength_plan_id': None, 'strength_plan_overlay_metadata': None, 'ratings': {'perceived_effort_rating': None}, 'is_3p_fit_feed_workout': False, 'is_non_partner_3p_fit_feed_workout': False, 'is_first_party_or_partner_3p_workout': True, 'pace_target_type': None, 'has_paused': False, 'is_pause_available': False, 'ride': {'content_availability': 'digital_and_above', 'content_availability_level': 'digital_and_above', 'free_for_limited_time': False, 'is_limited_ride': False, 'availability': {'is_available': True, 'reason': None}, 'class_type_ids': ['b6faaa4a53eb40d9a536041ae89b45bb'], 'content_provider': 'peloton', 'content_format': 'video', 'description': 'This yoga class focuses on poses that complement your hard work after a challenging run so you can be fresh and ready for your next workout.', 'difficulty_estimate': 5.088311688311689, 'overall_estimate': 1.0, 'difficulty_rating_avg': 5.088311688311689, 'difficulty_rating_count': 385, 'difficulty_level': None, 'duration': 1800, 'equipment_ids': [], 'equipment_tags': [], 'explicit_rating': 0, 'extra_images': [], 'fitness_discipline': 'yoga', 'fitness_discipline_display_name': 'Yoga', 'has_closed_captions': True, 'has_pedaling_metrics': False, 'home_peloton_id': '83a0434d14cf43748012fac750bf3a6c', 'id': '81a9a98b8c0f4e78b769b5945bcecbe8', 'image_url': 'https://s3.amazonaws.com/peloton-ride-images/81a9a98b8c0f4e78b769b5945bcecbe8/img_1d3aa993d5e74d5db83cd3c1fdf1aa91', 'instructor_id': '6c4b9f8582b84ab1bb1225d3e396e92e', 'individual_instructor_ids': [], 'is_archived': True, 'is_closed_caption_shown': True, 'is_explicit': False, 'has_free_mode': False, 'is_live_in_studio_only': False, 'language': 'english', 'origin_locale': 'en-US', 'length': 2003, 'live_stream_id': '81a9a98b8c0f4e78b769b5945bcecbe8-live', 'live_stream_url': None, 'location': 'psny-studio-2', 'metrics': ['heart_rate', 'calories'], 'original_air_time': 1758988529, 'overall_rating_avg': 1.0, 'overall_rating_count': 476, 'pedaling_start_offset': 60, 'pedaling_end_offset': 1860, 'pedaling_duration': 1800, 'rating': 0, 'ride_type_id': 'b6faaa4a53eb40d9a536041ae89b45bb', 'ride_type_ids': ['b6faaa4a53eb40d9a536041ae89b45bb'], 'sample_vod_stream_url': None, 'sample_preview_stream_url': None, 'scheduled_start_time': 1758988800, 'series_id': '221099bd69fd47629c7e3990521b7406', 'sold_out': False, 'studio_peloton_id': '3aa2d5d8bcbd47dea598e9bbe95b3e79', 'title': '30 min Focus Flow: For Runners', 'total_ratings': 1729, 'total_in_progress_workouts': 0, 'total_workouts': 10000, 'vod_stream_url': None, 'vod_stream_id': '81a9a98b8c0f4e78b769b5945bcecbe8-vod', 'captions': ['de-DE', 'en-US', 'es-ES'], 'user_caption_locales': [], 'join_tokens': {'on_demand': 'eyJob21lX3BlbG90b25faWQiOiBudWxsLCAicmlkZV9pZCI6ICI4MWE5YTk4YjhjMGY0ZTc4Yjc2OWI1OTQ1YmNlY2JlOCIsICJzdHVkaW9fcGVsb3Rvbl9pZCI6IG51bGwsICJ0eXBlIjogIm9uX2RlbWFuZCJ9'}, 'flags': [], 'is_dynamic_video_eligible': False, 'is_fixed_distance': False, 'dynamic_video_r ...
# --------------------------------------------------
# dict_keys(['created_at', 'device_type', 'end_time', 'fitness_discipline', 'has_pedaling_metrics', 'has_leaderboard_metrics', 'id', 'is_total_work_personal_record', 'is_outdoor', 'metrics_type', 'name', 'peloton_id', 'platform', 'start_time', 'status', 'timezone', 'title', 'total_work', 'user_id', 'workout_type', 'total_video_watch_time_seconds', 'total_video_buffering_seconds', 'v2_total_video_watch_time_seconds', 'v2_total_video_buffering_seconds', 'total_music_audio_play_seconds', 'total_music_audio_buffer_seconds', 'service_id', 'created', 'device_time_created_at', 'strava_id', 'fitbit_id', 'is_skip_intro_available', 'pause_time_remaining', 'pause_time_elapsed', 'is_paused', 'strength_plan_id', 'strength_plan_overlay_metadata', 'ratings', 'is_3p_fit_feed_workout', 'is_non_partner_3p_fit_feed_workout', 'is_first_party_or_partner_3p_workout', 'pace_target_type', 'has_paused', 'is_pause_available', 'ride', 'total_heart_rate_zone_durations', 'average_effort_score', 'achievement_templates', 'leaderboard_rank', 'total_leaderboard_users', 'leaderboard_distance_rank', 'total_leaderboard_distance_users', 'ftp_info', 'device_type_display_name', 'metadata', 'is_3p_digital_workout', 'performance_graph', 'instructor_name'])
# {'created_at': 1780313575, 'device_type': 'iPhone', 'end_time': 1780315601, 'fitness_discipline': 'yoga', 'has_pedaling_metrics': False, 'has_leaderboard_metrics': False, 'id': 'a8579ea91daf4a93b15016a307d8119b', 'is_total_work_personal_record': False, 'is_outdoor': False, 'metrics_type': None, 'name': 'Yoga Workout', 'peloton_id': '4e7c873ce58c4167b6088c315602f622', 'platform': 'iOS_app', 'start_time': 1780313635, 'status': 'COMPLETE', 'timezone': 'America/Detroit', 'title': None, 'total_work': 0.0, 'user_id': '8268ac98132549909d804933254576d5', 'workout_type': 'class', 'total_video_watch_time_seconds': 0, 'total_video_buffering_seconds': 0, 'v2_total_video_watch_time_seconds': 2027, 'v2_total_video_buffering_seconds': 1, 'total_music_audio_play_seconds': None, 'total_music_audio_buffer_seconds': None, 'service_id': None, 'created': 1780313575, 'device_time_created_at': 1780299175, 'strava_id': None, 'fitbit_id': None, 'is_skip_intro_available': True, 'pause_time_remaining': None, 'pause_time_elapsed': None, 'is_paused': False, 'strength_plan_id': None, 'strength_plan_overlay_metadata': None, 'ratings': {'perceived_effort_rating': None}, 'is_3p_fit_feed_workout': False, 'is_non_partner_3p_fit_feed_workout': False, 'is_first_party_or_partner_3p_workout': True, 'pace_target_type': None, 'has_paused': False, 'is_pause_available': False, 'ride': {'content_availability': 'digital_and_above', 'content_availability_level': 'digital_and_above', 'free_for_limited_time': False, 'is_limited_ride': False, 'availability': {'is_available': True, 'reason': None}, 'class_type_ids': ['56c834e143d4423799fc1d3f3fd70ec8'], 'content_provider': 'peloton', 'content_format': 'video', 'description': "In this active, vinyasa-style yoga class, we'll flow from one pose to the next, linking movements with the breath. Hone your inner focus as you develop strength, flexibility and balance.", 'difficulty_estimate': 6.427350427350428, 'overall_estimate': 0.9964788732394366, 'difficulty_rating_avg': 6.427350427350428, 'difficulty_rating_count': 234, 'difficulty_level': 'intermediate', 'duration': 1800, 'equipment_ids': [], 'equipment_tags': [], 'explicit_rating': 1, 'extra_images': [], 'fitness_discipline': 'yoga', 'fitness_discipline_display_name': 'Yoga', 'has_closed_captions': True, 'has_pedaling_metrics': False, 'home_peloton_id': '4c134348f0a247ecadeb1736873bbf85', 'id': 'a9f0a17ac7e441a89651d3efb95e867f', 'image_url': 'https://s3.amazonaws.com/peloton-ride-images/a9f0a17ac7e441a89651d3efb95e867f/img_a7d27b31c6244396a5d71584cca43c71', 'instructor_id': '6c4b9f8582b84ab1bb1225d3e396e92e', 'individual_instructor_ids': [], 'is_archived': True, 'is_closed_caption_shown': True, 'is_explicit': True, 'has_free_mode': False, 'is_live_in_studio_only': False, 'language': 'english', 'origin_locale': 'en-US', 'length': 2028, 'live_stream_id': 'a9f0a17ac7e441a89651d3efb95e867f-live', 'live_stream_url': None, 'location': 'psny-studio-2', 'metrics': ['heart_rate', 'calories'], 'original_air_time': 1777046185, 'overall_rating_avg': 0.9964788732394366, 'overall_rating_count': 284, 'pedaling_start_offset': 60, 'pedaling_end_offset': 1860, 'pedaling_duration': 1800, 'rating': 0, 'ride_type_id': '56c834e143d4423799fc1d3f3fd70ec8', 'ride_type_ids': ['56c834e143d4423799fc1d3f3fd70ec8'], 'sample_vod_stream_url': None, 'sample_preview_stream_url': None, 'scheduled_start_time': 1777046400, 'series_id': '23ade71a057b4809a3ef2ccfee814f98', 'sold_out': False, 'studio_peloton_id': 'fc7fa57ac5ca4afcaf24e54a76284257', 'title': '30 min Yoga Flow', 'total_ratings': 1029, 'total_in_progress_workouts': 0, 'total_workouts': 5000, 'vod_stream_url': None, 'vod_stream_id': 'a9f0a17ac7e441a89651d3efb95e867f-vod', 'captions': ['de-DE', 'en-US', 'es-ES'], 'user_caption_locales': [], 'join_tokens': {'on_demand': 'eyJob21lX3BlbG90b25faWQiOiBudWxsLCAicmlkZV9pZCI6ICJhOWYwYTE3YWM3ZTQ0MWE4OTY1MWQzZWZiOTVlODY3ZiIsICJzdHVkaW9fcGVsb3Rvbl9pZCI6IG51bGwsICJ0eXBlIjogIm9uX2RlbWFuZCJ9'}, 'flags': [], 'is_dynami ...
# --------------------------------------------------
# dict_keys(['created_at', 'device_type', 'end_time', 'fitness_discipline', 'has_pedaling_metrics', 'has_leaderboard_metrics', 'id', 'is_total_work_personal_record', 'is_outdoor', 'metrics_type', 'name', 'peloton_id', 'platform', 'start_time', 'status', 'timezone', 'title', 'total_work', 'user_id', 'workout_type', 'total_video_watch_time_seconds', 'total_video_buffering_seconds', 'v2_total_video_watch_time_seconds', 'v2_total_video_buffering_seconds', 'total_music_audio_play_seconds', 'total_music_audio_buffer_seconds', 'service_id', 'created', 'device_time_created_at', 'strava_id', 'fitbit_id', 'is_skip_intro_available', 'pause_time_remaining', 'pause_time_elapsed', 'is_paused', 'strength_plan_id', 'strength_plan_overlay_metadata', 'ratings', 'is_3p_fit_feed_workout', 'is_non_partner_3p_fit_feed_workout', 'is_first_party_or_partner_3p_workout', 'pace_target_type', 'has_paused', 'is_pause_available', 'ride', 'total_heart_rate_zone_durations', 'average_effort_score', 'achievement_templates', 'leaderboard_rank', 'total_leaderboard_users', 'leaderboard_distance_rank', 'total_leaderboard_distance_users', 'ftp_info', 'device_type_display_name', 'metadata', 'is_3p_digital_workout', 'performance_graph', 'instructor_name'])
# {'created_at': 1780236464, 'device_type': 'iPhone', 'end_time': 1780237898, 'fitness_discipline': 'yoga', 'has_pedaling_metrics': False, 'has_leaderboard_metrics': False, 'id': 'cddf1773fcfc42f7977928ba7b948e3f', 'is_total_work_personal_record': False, 'is_outdoor': False, 'metrics_type': None, 'name': 'Yoga Workout', 'peloton_id': '80eadea2bb2e4727bcde3a7ddc40801b', 'platform': 'iOS_app', 'start_time': 1780236524, 'status': 'COMPLETE', 'timezone': 'America/Detroit', 'title': None, 'total_work': 0.0, 'user_id': '8268ac98132549909d804933254576d5', 'workout_type': 'class', 'total_video_watch_time_seconds': 0, 'total_video_buffering_seconds': 0, 'v2_total_video_watch_time_seconds': 1435, 'v2_total_video_buffering_seconds': 1, 'total_music_audio_play_seconds': None, 'total_music_audio_buffer_seconds': None, 'service_id': None, 'created': 1780236464, 'device_time_created_at': 1780222063, 'strava_id': None, 'fitbit_id': None, 'is_skip_intro_available': True, 'pause_time_remaining': None, 'pause_time_elapsed': None, 'is_paused': False, 'strength_plan_id': None, 'strength_plan_overlay_metadata': None, 'ratings': {'perceived_effort_rating': None}, 'is_3p_fit_feed_workout': False, 'is_non_partner_3p_fit_feed_workout': False, 'is_first_party_or_partner_3p_workout': True, 'pace_target_type': None, 'has_paused': False, 'is_pause_available': False, 'ride': {'content_availability': 'unknown', 'content_availability_level': 'digital_basic_only_visibility', 'free_for_limited_time': False, 'is_limited_ride': False, 'availability': {'is_available': True, 'reason': None}, 'class_type_ids': ['56c834e143d4423799fc1d3f3fd70ec8'], 'content_provider': 'peloton', 'content_format': 'video', 'description': "In this active, vinyasa-style yoga class, we'll flow from one pose to the next, linking movements with the breath. Hone your inner focus as you develop strength, flexibility and balance.", 'difficulty_estimate': 5.0, 'overall_estimate': 1.0, 'difficulty_rating_avg': 5.0, 'difficulty_rating_count': 1, 'difficulty_level': 'intermediate', 'duration': 1200, 'equipment_ids': [], 'equipment_tags': [], 'explicit_rating': 0, 'extra_images': [], 'fitness_discipline': 'yoga', 'fitness_discipline_display_name': 'Yoga', 'has_closed_captions': True, 'has_pedaling_metrics': False, 'home_peloton_id': '95fdc4bbf75144399495c2bc8dc7bc7f', 'id': '0f3039959cc84e9f83bc705e6d76d30d', 'image_url': 'https://s3.amazonaws.com/peloton-ride-images/0f3039959cc84e9f83bc705e6d76d30d/img_bddcbf14b92649b4ad9d733cd9079357', 'instructor_id': '6c4b9f8582b84ab1bb1225d3e396e92e', 'individual_instructor_ids': [], 'is_archived': True, 'is_closed_caption_shown': True, 'is_explicit': False, 'has_free_mode': False, 'is_live_in_studio_only': False, 'language': 'english', 'origin_locale': 'en-US', 'length': 1436, 'live_stream_id': '0f3039959cc84e9f83bc705e6d76d30d-live', 'live_stream_url': None, 'location': 'psny-studio-2', 'metrics': ['heart_rate', 'calories'], 'original_air_time': 1750197474, 'overall_rating_avg': 1.0, 'overall_rating_count': 1, 'pedaling_start_offset': 60, 'pedaling_end_offset': 1260, 'pedaling_duration': 1200, 'rating': 0, 'ride_type_id': '56c834e143d4423799fc1d3f3fd70ec8', 'ride_type_ids': ['56c834e143d4423799fc1d3f3fd70ec8'], 'sample_vod_stream_url': None, 'sample_preview_stream_url': None, 'scheduled_start_time': 1750197600, 'series_id': '23ade71a057b4809a3ef2ccfee814f98', 'sold_out': False, 'studio_peloton_id': 'fd39244888e64ade9e9bd04d082fdba9', 'title': '20 min Yoga Flow', 'total_ratings': 2, 'total_in_progress_workouts': 0, 'total_workouts': 0, 'vod_stream_url': None, 'vod_stream_id': '0f3039959cc84e9f83bc705e6d76d30d-vod', 'captions': ['de-DE', 'en-US', 'es-ES'], 'user_caption_locales': [], 'join_tokens': {'on_demand': 'eyJob21lX3BlbG90b25faWQiOiBudWxsLCAicmlkZV9pZCI6ICIwZjMwMzk5NTljYzg0ZTlmODNiYzcwNWU2ZDc2ZDMwZCIsICJzdHVkaW9fcGVsb3Rvbl9pZCI6IG51bGwsICJ0eXBlIjogIm9uX2RlbWFuZCJ9'}, 'flags': [], 'is_dynamic_video_eligible': False, 'is_fixed_distance': False, 'dynamic_vi ...
# --------------------------------------------------

# %%
workouts[0].keys()
# Out:
# dict_keys(['created_at', 'device_type', 'end_time', 'fitness_discipline', 'has_pedaling_metrics', 'has_leaderboard_metrics', 'id', 'is_total_work_personal_record', 'is_outdoor', 'metrics_type', 'name', 'peloton_id', 'platform', 'start_time', 'status', 'timezone', 'title', 'total_work', 'user_id', 'workout_type', 'total_video_watch_time_seconds', 'total_video_buffering_seconds', 'v2_total_video_watch_time_seconds', 'v2_total_video_buffering_seconds', 'total_music_audio_play_seconds', 'total_music_audio_buffer_seconds', 'service_id', 'created', 'device_time_created_at', 'strava_id', 'fitbit_id', 'is_skip_intro_available', 'pause_time_remaining', 'pause_time_elapsed', 'is_paused', 'strength_plan_id', 'strength_plan_overlay_metadata', 'ratings', 'is_3p_fit_feed_workout', 'is_non_partner_3p_fit_feed_workout', 'is_first_party_or_partner_3p_workout', 'pace_target_type', 'has_paused', 'is_pause_available', 'ride', 'total_heart_rate_zone_durations', 'average_effort_score', 'achievement_templates', 'leaderboard_rank', 'total_leaderboard_users', 'leaderboard_distance_rank', 'total_leaderboard_distance_users', 'ftp_info', 'device_type_display_name', 'metadata', 'is_3p_digital_workout', 'performance_graph', 'instructor_name'])

# %%
workout = workouts[0]

print(workout["title"])
print(workout["instructor_name"])
print(workout["fitness_discipline"])
print(workout["created_at"])
print(workout["ride"])
# Out:
# None
# Kirra Michel
# yoga
# 1780487378
# {'content_availability': 'digital_and_above', 'content_availability_level': 'digital_and_above', 'free_for_limited_time': False, 'is_limited_ride': False, 'availability': {'is_available': True, 'reason': None}, 'class_type_ids': ['56c834e143d4423799fc1d3f3fd70ec8'], 'content_provider': 'peloton', 'content_format': 'video', 'description': "In this active, vinyasa-style yoga class, we'll flow from one pose to the next, linking movements with the breath. Hone your inner focus as you develop strength, flexibility and balance.", 'difficulty_estimate': 6.090534979423868, 'overall_estimate': 1.0, 'difficulty_rating_avg': 6.090534979423868, 'difficulty_rating_count': 243, 'difficulty_level': 'intermediate', 'duration': 1800, 'equipment_ids': [], 'equipment_tags': [], 'explicit_rating': 0, 'extra_images': [], 'fitness_discipline': 'yoga', 'fitness_discipline_display_name': 'Yoga', 'has_closed_captions': True, 'has_pedaling_metrics': False, 'home_peloton_id': '7951f237311b47e087fda664058d971e', 'id': '7092dd7db4b94b22b855494e4255173a', 'image_url': 'https://s3.amazonaws.com/peloton-ride-images/7092dd7db4b94b22b855494e4255173a/img_bd762739d8ab486e886203c86e8ca23d', 'instructor_id': '6c4b9f8582b84ab1bb1225d3e396e92e', 'individual_instructor_ids': [], 'is_archived': True, 'is_closed_caption_shown': True, 'is_explicit': False, 'has_free_mode': False, 'is_live_in_studio_only': False, 'language': 'english', 'origin_locale': 'en-US', 'length': 2032, 'live_stream_id': '7092dd7db4b94b22b855494e4255173a-live', 'live_stream_url': None, 'location': 'psny-studio-2', 'metrics': ['heart_rate', 'calories'], 'original_air_time': 1769793961, 'overall_rating_avg': 1.0, 'overall_rating_count': 284, 'pedaling_start_offset': 60, 'pedaling_end_offset': 1860, 'pedaling_duration': 1800, 'rating': 0, 'ride_type_id': '56c834e143d4423799fc1d3f3fd70ec8', 'ride_type_ids': ['56c834e143d4423799fc1d3f3fd70ec8'], 'sample_vod_stream_url': None, 'sample_preview_stream_url': None, 'scheduled_start_time': 1769794200, 'series_id': '23ade71a057b4809a3ef2ccfee814f98', 'sold_out': False, 'studio_peloton_id': '9416a48287d34349a35f8ea5d5d8003e', 'title': '30 min Yoga Flow', 'total_ratings': 953, 'total_in_progress_workouts': 0, 'total_workouts': 10000, 'vod_stream_url': None, 'vod_stream_id': '7092dd7db4b94b22b855494e4255173a-vod', 'captions': ['de-DE', 'en-US', 'es-ES'], 'user_caption_locales': [], 'join_tokens': {'on_demand': 'eyJob21lX3BlbG90b25faWQiOiBudWxsLCAicmlkZV9pZCI6ICI3MDkyZGQ3ZGI0Yjk0YjIyYjg1NTQ5NGU0MjU1MTczYSIsICJzdHVkaW9fcGVsb3Rvbl9pZCI6IG51bGwsICJ0eXBlIjogIm9uX2RlbWFuZCJ9'}, 'flags': [], 'is_dynamic_video_eligible': False, 'is_fixed_distance': False, 'dynamic_video_recorded_speed_in_mph': None, 'thumbnail_title': '', 'thumbnail_location': '', 'distance': None, 'distance_unit': None, 'distance_display_value': None, 'is_outdoor': False, 'has_tread_pace_target': False, 'excluded_platforms': [], 'class_avg_follow_along_score': 0.0, 'muscle_group_score': [{'muscle_group': 'biceps', 'score': 678.0, 'percentage': 2, 'bucket': 1, 'display_name': 'Biceps'}, {'muscle_group': 'calves', 'score': 2797.083333333333, 'percentage': 7, 'bucket': 2, 'display_name': 'Calves'}, {'muscle_group': 'chest', 'score': 1751.0, 'percentage': 5, 'bucket': 2, 'display_name': 'Chest'}, {'muscle_group': 'core', 'score': 2975.916666666667, 'percentage': 8, 'bucket': 2, 'display_name': 'Core'}, {'muscle_group': 'forearms', 'score': 1035.6666666666667, 'percentage': 3, 'bucket': 1, 'display_name': 'Forearms'}, {'muscle_group': 'glutes', 'score': 3843.166666666667, 'percentage': 10, 'bucket': 3, 'display_name': 'Glutes'}, {'muscle_group': 'hamstrings', 'score': 3485.5, 'percentage': 9, 'bucket': 3, 'display_name': 'Hamstrings'}, {'muscle_group': 'hips', 'score': 3196.416666666667, 'percentage': 9, 'bucket': 3, 'display_name': 'Hips'}, {'muscle_group': 'lats', 'score': 2150.3333333333335, 'percentage': 6, 'bucket': 2, 'display_name': 'Lats'}, {'muscle_group': 'low_back', 'score': 3196.4166666666665, ' ...

# %%
workout["ride"].keys()
# Out:
# dict_keys(['content_availability', 'content_availability_level', 'free_for_limited_time', 'is_limited_ride', 'availability', 'class_type_ids', 'content_provider', 'content_format', 'description', 'difficulty_estimate', 'overall_estimate', 'difficulty_rating_avg', 'difficulty_rating_count', 'difficulty_level', 'duration', 'equipment_ids', 'equipment_tags', 'explicit_rating', 'extra_images', 'fitness_discipline', 'fitness_discipline_display_name', 'has_closed_captions', 'has_pedaling_metrics', 'home_peloton_id', 'id', 'image_url', 'instructor_id', 'individual_instructor_ids', 'is_archived', 'is_closed_caption_shown', 'is_explicit', 'has_free_mode', 'is_live_in_studio_only', 'language', 'origin_locale', 'length', 'live_stream_id', 'live_stream_url', 'location', 'metrics', 'original_air_time', 'overall_rating_avg', 'overall_rating_count', 'pedaling_start_offset', 'pedaling_end_offset', 'pedaling_duration', 'rating', 'ride_type_id', 'ride_type_ids', 'sample_vod_stream_url', 'sample_preview_stream_url', 'scheduled_start_time', 'series_id', 'sold_out', 'studio_peloton_id', 'title', 'total_ratings', 'total_in_progress_workouts', 'total_workouts', 'vod_stream_url', 'vod_stream_id', 'captions', 'user_caption_locales', 'join_tokens', 'flags', 'is_dynamic_video_eligible', 'is_fixed_distance', 'dynamic_video_recorded_speed_in_mph', 'thumbnail_title', 'thumbnail_location', 'distance', 'distance_unit', 'distance_display_value', 'is_outdoor', 'has_tread_pace_target', 'excluded_platforms', 'class_avg_follow_along_score', 'muscle_group_score'])

# %%
workout = workouts[0]

ride_id = workout["ride"]["id"]
print(ride_id)

url = f"https://members.onepeloton.com/classes/yoga?modal=classDetailsModal&classId={ride_id}"
print(url)
# Out:
# 7092dd7db4b94b22b855494e4255173a
# https://members.onepeloton.com/classes/yoga?modal=classDetailsModal&classId=7092dd7db4b94b22b855494e4255173a

# %%
all_workouts = peloton.GetRecentWorkouts(600)

# %%
disciplines = set(
    w["fitness_discipline"]
    for w in all_workouts
)

print(disciplines)
# Out:
# {'cycling', 'walking', 'yoga'}

# %%
yoga = [
    w for w in all_workouts
    if w["fitness_discipline"] == "yoga"
]

print(len(yoga))
# Out:
# 513

# %%
import pandas as pd

rows = []

for w in all_workouts:
    if w.get("fitness_discipline") != "yoga":
        continue

    ride = w.get("ride", {})

    rows.append({
        "class_id": ride.get("id"),
        "title": ride.get("title") or w.get("title"),
        "instructor": w.get("instructor_name"),
        "duration_min": ride.get("duration", 0) // 60,
        "original_air_date": pd.to_datetime(
            ride.get("original_air_time"), unit="s", errors="coerce"
        ).date(),
        "description": ride.get("description"),
        "thumbnail_title": ride.get("thumbnail_title"),
        "difficulty": ride.get("difficulty_rating_avg"),
        "taken_date": pd.to_datetime(w.get("created_at"), unit="s").date(),
        "peloton_url": f"https://members.onepeloton.com/classes/yoga?modal=classDetailsModal&classId={ride.get('id')}",
        "image_url": ride.get("image_url"),
    })
    

df = pd.DataFrame(rows)

summary = (
    df.groupby(
        ["class_id", "title", "instructor", "duration_min", "original_air_date", 
        "description", "peloton_url", "image_url"],
        dropna=False
    )
    .agg(
        times_taken=("taken_date", "count"),
        last_taken=("taken_date", "max"),
        dates_taken=("taken_date", lambda x: ", ".join(str(d) for d in sorted(x)))
    )
    .reset_index()
    .sort_values(["times_taken", "last_taken"], ascending=[False, False])
)

# %%
summary.to_csv("peloton_yoga_lookup.csv", index=False)

# %%
summary.sort_values("times_taken", ascending=False).head(20)
# Out:
#                              class_id                      title  \
# 326  e9715cbffc384f99be07a4e4132ded61           10 min Yoga Flow
# 107  49957a41f4554f239b2e1fe398e7b1cd           10 min Yoga Flow
# 272  c885409b3ce645c79064f26d6ad9abb5           10 min Yoga Flow
# 313  e0809960d3aa48aaa404e11d908a8174           15 min Yoga Flow
# 323  e8011d0bfaa649fc9756bfe0ccbc773a           10 min Yoga Flow
# 32   138471946d4347bf8ff68780ede83d82           20 min Yoga Flow
# 134  6234bdd4cacf4b4098705dfe9364c686           10 min Yoga Flow
# 140  678be67c9bda458a9aec6faadd3b5e7c           10 min Yoga Flow
# 124  5968e3910c53408c93dd60fa17e4fcd2           20 min Yoga Flow
# 240  ab042c427ba444adbdf376f523403ac8           10 min Yoga Flow
# 163  76a4c414681a49d8a3770da1407585a7           15 min Yoga Flow
# 129  5df94ed96c3e4b0fb6deca05790afe23           10 min Yoga Flow
# 96   4211687018c34980992df581a0f42c13           20 min Yoga Flow
# 259  bc1675241b934256b063c8961284d2b7           20 min Yoga Flow
# 312  dfb9848b8991408181f73a07be1058cd           20 min Yoga Flow
# 243  ae24818d11db47c4ba47641cd7968467   20 min Morning Yoga Flow
# 146  6a3d1146509a43f1a263a448497ba4dc           20 min Yoga Flow
# 344  f7e2408a59214fc8b26ffb3a1b6730af  20 min Grounded Yoga Flow
# 236  a9baf15c83f74df19336b6c31b274aed           20 min Yoga Flow
# 95   420c3840c5864289957c816a7275718b           20 min Yoga Flow
#
#        instructor  duration_min original_air_date  \
# 326  Kirra Michel            10        2023-05-18
# 107  Kirra Michel            10        2022-09-01
# 272  Kirra Michel            10        2024-04-09
# 313  Kirra Michel            15        2022-04-29
# 323  Kirra Michel            10        2023-01-12
# 32   Kirra Michel            20        2024-12-03
# 134  Kirra Michel            10        2023-04-13
# 140  Kirra Michel            10        2023-02-23
# 124  Kirra Michel            20        2023-09-05
# 240  Kirra Michel            10        2021-06-12
# 163  Kirra Michel            15        2023-01-19
# 129  Kirra Michel            10        2024-02-06
# 96   Kirra Michel            20        2024-01-23
# 259  Kirra Michel            20        2023-02-27
# 312  Kirra Michel            20        2023-04-06
# 243  Kirra Michel            20        2024-06-20
# 146  Kirra Michel            20        2023-07-06
# 344  Kirra Michel            20        2023-08-08
# 236  Kirra Michel            20        2025-02-01
# 95   Kirra Michel            20        2025-03-18
#
#                                            description  \
# 326  In this active, vinyasa-style yoga class, we'l...
# 107  In this active, vinyasa-style yoga class, we'l...
# 272  In this active, vinyasa-style yoga class, we'l...
# 313  In this active, vinyasa-style yoga class, we'l...
# 323  In this active, vinyasa-style yoga class, we'l...
# 32   In this active, vinyasa-style yoga class, we'l...
# 134  In this active, vinyasa-style yoga class, we'l...
# 140  In this active, vinyasa-style yoga class, we'l...
# 124  In this active, vinyasa-style yoga class, we'l...
# 240  In this active, vinyasa-style yoga class, we'l...
# 163  In this active, vinyasa-style yoga class, we'l...
# 129  In this active, vinyasa-style yoga class, we'l...
# 96   In this active, vinyasa-style yoga class, we'l...
# 259  In this active, vinyasa-style yoga class, we'l...
# 312  In this active, vinyasa-style yoga class, we'l...
# 243  Kirra designed this yoga sequence to help you ...
# 146  In this active, vinyasa-style yoga class, we'l...
# 344  In this active, vinyasa-style yoga class, we'l...
# 236  In this active, vinyasa-style yoga class, we'l...
# 95   In this active, vinyasa-style yoga class, we'l...
#
#                                            peloton_url  \
# 326  https://members.onepeloton.com/classes/yoga?mo...
# 107  https://members.onepeloton.com/classes/yoga?mo...
# 272  https://members.onepeloton.com/classes/yoga?mo...
# 313  https://members.onepeloton.com/classes/yoga?mo...
# 323  https://members.onepeloton.com/classes/yoga?mo...
# 32   https://members.onepeloton.com/classes/yoga?mo...
# 134  https://members.onepeloton.com/classes/yoga?mo...
# 140  https://members.onepeloton.com/classes/yoga?mo...
# 124  https://members.onepeloton.com/classes/yoga?mo...
# 240  https://members.onepeloton.com/classes/yoga?mo...
# 163  https://members.onepeloton.com/classes/yoga?mo...
# 129  https://members.onepeloton.com/classes/yoga?mo...
# 96   https://members.onepeloton.com/classes/yoga?mo...
# 259  https://members.onepeloton.com/classes/yoga?mo...
# 312  https://members.onepeloton.com/classes/yoga?mo...
# 243  https://members.onepeloton.com/classes/yoga?mo...
# 146  https://members.onepeloton.com/classes/yoga?mo...
# 344  https://members.onepeloton.com/classes/yoga?mo...
# 236  https://members.onepeloton.com/classes/yoga?mo...
# 95   https://members.onepeloton.com/classes/yoga?mo...
#
#                                              image_url  times_taken  \
# 326  https://s3.amazonaws.com/peloton-ride-images/6...            7
# 107  https://s3.amazonaws.com/peloton-ride-images/3...            6
# 272  https://s3.amazonaws.com/peloton-ride-images/7...            6
# 313  https://s3.amazonaws.com/peloton-ride-images/0...            6
# 323  https://s3.amazonaws.com/peloton-ride-images/0...            6
# 32   https://s3.amazonaws.com/peloton-ride-images/2...            5
# 134  https://s3.amazonaws.com/peloton-ride-images/7...            5
# 140  https://s3.amazonaws.com/peloton-ride-images/7...            5
# 124  https://s3.amazonaws.com/peloton-ride-images/f...            4
# 240  https://s3.amazonaws.com/peloton-ride-images/5...            4
# 163  https://s3.amazonaws.com/peloton-ride-images/0...            4
# 129  https://s3.amazonaws.com/peloton-ride-images/7...            4
# 96   https://s3.amazonaws.com/peloton-ride-images/3...            4
# 259  https://s3.amazonaws.com/peloton-ride-images/b...            4
# 312  https://s3.amazonaws.com/peloton-ride-images/3...            4
# 243  https://s3.amazonaws.com/peloton-ride-images/f...            4
# 146  https://s3.amazonaws.com/peloton-ride-images/f...            4
# 344  https://s3.amazonaws.com/peloton-ride-images/b...            4
# 236  https://s3.amazonaws.com/peloton-ride-images/e...            4
# 95   https://s3.amazonaws.com/peloton-ride-images/c...            4
#
#      last_taken                                        dates_taken
# 326  2024-08-08  2024-03-13, 2024-04-17, 2024-06-08, 2024-06-22...
# 107  2024-08-22  2024-04-01, 2024-04-22, 2024-06-05, 2024-06-28...
# 272  2024-08-21  2024-04-12, 2024-05-29, 2024-06-10, 2024-06-27...
# 313  2024-08-16  2024-05-24, 2024-07-10, 2024-07-16, 2024-07-23...
# 323  2024-11-17  2024-03-25, 2024-04-19, 2024-07-05, 2024-08-03...
# 32   2025-05-14  2024-12-04, 2025-02-11, 2025-02-21, 2025-03-06...
# 134  2024-08-19  2024-03-14, 2024-05-31, 2024-06-06, 2024-06-24...
# 140  2024-07-13  2024-03-28, 2024-04-24, 2024-05-17, 2024-06-26...
# 124  2025-04-09     2024-10-14, 2024-11-08, 2025-01-24, 2025-04-09
# 240  2024-08-20     2024-03-27, 2024-04-23, 2024-05-21, 2024-08-20
# 163  2024-09-04     2024-07-11, 2024-07-18, 2024-08-05, 2024-09-04
# 129  2024-09-11     2024-02-12, 2024-05-20, 2024-06-11, 2024-09-11
# 96   2025-01-27     2024-09-13, 2024-11-11, 2025-01-02, 2025-01-27
# 259  2025-03-17     2024-09-17, 2024-12-20, 2025-02-24, 2025-03-17
# 312  2025-03-18     2024-09-23, 2024-12-31, 2025-02-13, 2025-03-18
# 243  2025-05-06     2024-09-09, 2024-10-31, 2025-01-22, 2025-05-06
# 146  2025-05-09     2024-10-29, 2025-03-24, 2025-04-08, 2025-05-09
# 344  2025-05-13     2024-10-15, 2024-11-12, 2025-02-12, 2025-05-13
# 236  2025-06-06     2025-03-19, 2025-03-31, 2025-05-01, 2025-06-06
# 95   2025-06-23     2025-03-21, 2025-05-02, 2025-05-27, 2025-06-23

# %%
ride_id = workout["ride"]["id"]

url = f"https://members.onepeloton.com/classes/yoga?modal=classDetailsModal&classId={ride_id}"

print(url)
# Out:
# https://members.onepeloton.com/classes/yoga?modal=classDetailsModal&classId=7092dd7db4b94b22b855494e4255173a
